# %% [markdown]
# <a href="https://colab.research.google.com/github/ubizareie/python-DA/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import ticker
import seaborn as sns

# %% [markdown]
# 1. Load the data source (either from a local file or from the web)
# 2. Explore and describe the data
# a. Show how the data is distributed.

# %%
from numpy.ma.core import count
df = pd.read_csv('https://raw.githubusercontent.com/ubizareie/python-DA/main/StudentsPerformance.csv.xls')
print (df.info())# Geting a big picture of data, types of data and general information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %% [markdown]
# b. Determine frequency of values in columns for categorical variables.

# %%
print (df['gender'].value_counts())# Finding the frequency of catogorical or nominal vaiables among the sample of study (students)
print (df['race/ethnicity'].value_counts())
print (df['parental level of education'].value_counts())
print (df['lunch'].value_counts())
print (df['test preparation course']. value_counts())
# Out:
# female    518
# male      482
# Name: gender, dtype: int64
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
freq = {} # Bar chart of the number of respondents based on their gender
for gender1 in df['gender']:
  if gender1 in freq.keys():
    freq[gender1] +=1
  else:
    freq[gender1] = 1
plt.figure(figsize= (5,6), dpi =70)
plt.bar(freq.keys(), freq.values(), color = '#9ca832', ec= 'black',ls= ':', linewidth = 1.5)
plt.xticks(rotation =25)
plt.title("Students' Gender", fontsize= 12)
plt.xlabel('Gender', fontsize= 12)
plt.ylabel('Number of Students', fontsize =12)
plt.show()

# %%
values=df['gender'].value_counts()# distrobution of students
plt.pie(values,labels = values.index, radius = 1.2, autopct ='%0.0f%%', shadow =True ,explode =[0,.05], startangle = 75, colors= [ '#32a869','#a83250'],labeldistance= 1.1)
plt.title('Distribution of students based on Gender', c='black' , weight= 'bold')
plt.show()

# %%
freq = {} # Bar chart of the number of respondents based on their race
for race in df['race/ethnicity']:
    if race in freq.keys():
        freq[race] +=1
    else:
        freq[race] = 1
plt.figure(figsize= (5,7), dpi=70)
plt.bar(list(freq.keys()), list(freq.values()), facecolor = '#32a83c' ,edgecolor ='red', ls= '-.',linewidth=.7)
plt.xticks(rotation =45)
plt.title('Race/Ethnicity of students', fontsize= 12)
plt.xlabel('Race/Ethnicity', fontsize= 11)
plt.ylabel('Number of students', fontsize=11)
plt.show()

# %%
values=df['race/ethnicity'].value_counts()
plt.pie(values,labels = values.index, radius = 1.2, autopct ='%0.0f%%', shadow =True ,explode =[0.02,0.02,0.02,0.02,0.02], startangle = 75, colors= [ '#a2a832','#a83250','#a8329e','#3265a8','#32a869'],labeldistance= 1.1)
plt.title('Distribution of students based on Race', c='black' , weight= 'bold')
plt.show()

# %%
freq = {}
for par_edu in df['parental level of education']:
    if par_edu in freq.keys():
        freq[par_edu] +=1
    else:
        freq[par_edu] = 1
plt.figure(figsize= (6,5), facecolor= 'white', edgecolor= 'black', dpi = 80)
          
plt.barh(list(freq.keys()), list(freq.values()), color ='teal', edgecolor = 'black', ls= '--')
plt.xticks(rotation =0, c= 'black')
plt.title('Parents education')
plt.xlabel('Number of Respondents')
plt.ylabel('Level of Education')
plt.show()

# %%
values=df['parental level of education'].value_counts()
plt.pie(values,labels = values.index, radius = 1.1, autopct ='%0.0f%%', shadow =True ,explode =[0.03,.02,.02,.02,0.02,.02], startangle = 75, colors= ['#4287f5', '#f542e9', '#42f54e','#f59942','#a83232','#f55142'],labeldistance= 1.1)
plt.title ('Parental level of education', c ='black' , weight= 'extra bold')
plt.title 
plt.show()

# %%
freq ={}
for lunch1 in df['lunch']:
  if lunch1 in freq.keys():
    freq[lunch1] += 1
  else:
    freq[lunch1] = 1
plt.figure(figsize= (5,5), dpi =80)
plt.bar(list(freq.keys()), list(freq.values()),color= '#328ca8', ec= 'black' )
plt.title("Studen's Lunch Program",fontsize= 12)
plt.xlabel('lunch program', fontsize=11)
plt.ylabel('Number of Respondents', fontsize=11)
plt.show()

# %%
freq = {}
for test_prep in df ['test preparation course']:
    if test_prep in freq.keys():
        freq [test_prep] += 1
    else:
        freq [test_prep] = 1
plt.bar(list(freq.keys()), list(freq.values()), color ='crimson')
plt.show()

# %% [markdown]
# c. Create a histogram for all continuous variables.

# %%
plt.hist(['math score', 'reading score', 'writing score'])# Histogram for numeric/continuous variables
plt.show ()

# %%
df.describe()[['math score', 'reading score', 'writing score']]
# Out:
#        math score  reading score  writing score
# count  992.000000    1000.000000    1000.000000
# mean    66.480847      69.169000      68.054000
# std     14.559999      14.600192      15.195657
# min     27.000000      17.000000      10.000000
# 25%     57.000000      59.000000      57.750000
# 50%     66.000000      70.000000      69.000000
# 75%     77.000000      79.000000      79.000000
# max    100.000000     100.000000     100.000000

# %%
print(df.mean());
print(df.median());
# Out:
# math score       66.480847
# reading score    69.443662
# writing score    68.306533
# dtype: float64
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
print('Math Score - Median')# Calculation the central tendency
print(df['math score'].median())
print('Math Score - Mean') 
print(df['math score'].mean())
print('Math Score - Mode')
print(df['math score'].mode())
print(df['math score'].mode()[0])# where [0] gives the highest number
print('Reading Score - Median')
print(df['reading score'].median()) 
print('Reading Score - Mean') 
print(df['reading score'].mean())
print('Reading Score - Mode')
print(df['reading score'].mode()[0])
print('writing score - Median') 
print(df['writing score'].median())
print('writing score - Mean') 
print(df['writing score'].mean())
print('writing score - Mode')
print(df['writing score'].mode()[0])
# Out:
# Math Score - Median
# 66.0
# Math Score - Mean
# 66.48084677419355
# Math Score - Mode
# 0    65.0
# dtype: float64
# 65.0
# Reading Score - Median
# 70.0
# Reading Score - Mean
# 69.44366197183099
# Reading Score - Mode
# 72.0
# writing score - Median
# 69.0
# writing score - Mean
# 68.30653266331659
# writing score - Mode
# 74.0

# %%
plt.boxplot(df['math score']) # Distribution of students(respondents) in 1st, 2nd, and 3rd quartile
plt.title('Math score')
plt.show()
plt.boxplot(df['reading score'])
plt.title('reading score')
plt.show()
plt.boxplot(df['writing score'])
plt.title('Writing score')
plt.show()

# %% [markdown]
# **d. Show any outliers in your data.**

# %%
sns.set_theme(color_codes=True) # Outliers in the dataset
sns.boxplot(df['math score']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['reading score']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
 var = sns.boxplot(df['writing score']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **i. Describe how the outliers impact your analysis and how you might need to deal with this.**
# Plot Boxes distribution of data show that there are a few outlires in all of the variables, and they are not significantly affecting the analysis. Outlier values are more in math scores than reading and writing scores. In other words,the range of scores(min and max) in math is higher than in reading and writing scores.

# %%
for x in ['writing score']: # Removing outliers from writing scores
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %% [markdown]
#  **Remove the outlier if there is any or needed**

# %%
for x in ['math score']: # Removing outliers from math scores
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %%
sns.set_theme(color_codes=True)# distribution of scores after removing the outliers
sns.boxplot(df['math score']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from numpy.lib.function_base import median
print(df['math score'].median())
# Out:
# 66.0

# %%
for x in ['reading score']:# Removing outliers from mreading scores
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %%
sns.set_theme(color_codes=True)# distribution of scores after removing the outliers
sns.boxplot(df['reading score']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(df['reading score'].median())
# Out:
# 70.0

# %%
for x in ['reading score']:# Removing outliers from mreading scores
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %%
sns.set_theme(color_codes=True)# distribution of scores after removing the outliers
sns.boxplot(df['writing score']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(df['writing score'].median())
# Out:
# 69.0

# %% [markdown]
# Although removing outliers changed very slightly the qurtiles, however it did not change the median in all three scores. The outliers are a few to affect the result of the study. That says meadian in math scores is 66, while it's 70 and 69 in reading and wrting respectively.

# %% [markdown]
# **e. Discuss any missing data points including why the data is missing and how it might affect your analysis. Describe your strategy for dealing with the missing data.**

# %% [markdown]
# This data set does not have any missing data.However, there is techniques for handling the missing data:
#
# 1- By far, the most common approach to the missing data is to simply omit those cases with the missing data and analyze the remaining data. This approach is known as the complete case (or available case) analysis or listwise deletion.
# 2- Pairwise deletion eliminates information only when the particular data-point needed to test a particular assumption is missing. If there is missing data elsewhere in the data set, the existing values are used in the statistical testing.
# 3- In a mean substitution, the mean value of a variable is used in place of the missing data value for that same variable. This allows the researchers to utilize the collected data in an incomplete dataset.
# 4- Imputation is the process of replacing the missing data with estimated values. Instead of deleting any case that has any missing value, this approach preserves all cases by replacing the missing data with a probable value estimated by other available information.
#
# Kang, Hyun,The prevention and handling of the missing data,Korean J Anesthesiol, 2013 May; 64(5): 402–406. doi: 10.4097/
# ### https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3668100/

# %%
print(df['math score'] .corr (df['reading score'])) # Calculating the correlation between students' math score and reading score. It's a strong positive relationship.
# Out:
# 0.8175796636720546

# %%
sns.scatterplot(data=df, x= 'math score', y= 'reading score')# correlation plot between students' math and reading scores
sns.regplot(x='math score', y='reading score', data=df);

# %%
print(df['math score'] .corr (df['writing score']))
# Out:
# 0.8026420459498085

# %%
sns.scatterplot(data=df, x= 'math score', y= 'writing score')#  positive relationship between students' math score and  writing score
sns.regplot(x='math score', y='writing score', data=df);

# %%
print(df['reading score'].corr(df['writing score']))# The strong positive correlation is between reaing score and wrting score
# Out:
# 0.9545980771462476

# %%
sns.scatterplot(data=df, x= 'writing score', y= 'reading score')
sns.set_theme(color_codes=True)
sns.regplot(x='writing score', y='reading score', data=df);

# %%
sns.scatterplot(data=df, x= 'math score', y= 'reading score')
sns.regplot(data=df, x= 'math score', y= 'reading score')
sns.set_theme(color_codes=True)
sns.scatterplot(data=df, x= 'reading score', y= 'writing score');# Here I add writing score in yellow color 
# to show where its score stands among the math and reading score

# %%
sns.set_theme(color_codes=True)# correlation between gender and exam scores. While male students do better than female students in math, female students outperformed male students in reading and wrtings.
sns.catplot(data= df, x='math score', y= 'gender', palette="ch:25");
sns.catplot(data=df, x= 'reading score', y = 'gender', palette='ch:.25');
sns.catplot(data=df, x= 'writing score', y ='gender' , palette='ch:.25');

# %%
sns.set_theme(color_codes=True) # The correlation between race/ethnicity and exam scores. In all three subjects students in group E Outperforms other groupds of ethniciy. Group A has the least among them.
sns.catplot(data= df, x='math score', y= 'race/ethnicity', kind= 'bar');
sns.catplot(data=df, x= 'reading score', y = 'race/ethnicity', kind = 'bar');
sns.catplot(data=df, x= 'writing score', y ='race/ethnicity', kind ='bar');

# %%
sns.set_theme(color_codes=True)# parental education level and the students' scores. Student's with higher educated parents have the highest scores in threes subjects. 
sns.catplot(data= df, x='math score', y= 'parental level of education',kind ='bar');
sns.catplot(data=df, x= 'reading score', y = 'parental level of education',kind ='bar');
sns.catplot(data=df, x= 'writing score', y ='parental level of education',kind ='bar');

# %%
sns.set_theme(color_codes=True)# How the standard or free/reduced lunch program plays a role in students' performance
sns.catplot(data= df, x='math score', y= 'lunch', palette='ch:.25'); # Here, I use palette graph rather than the bar chart. Bar chart compares scores based on the mean while platter shows the data's distrbution based on the actual score.
sns.catplot(data=df, x= 'reading score', y = 'lunch', palette='ch:.25');
sns.catplot(data=df, x= 'writing score', y ='lunch' , palette='ch:.25');

# %%
sns.set_theme(color_codes=True)# Test preparation and exam scores. Students participated in test preparation course significantly outperfomed who have not attend in the course.
sns.catplot(data=df, y="test preparation course", x="math score", palette="ch:25");
sns.catplot(data=df, y="test preparation course", x="reading score",palette="ch:25");
sns.catplot(data=df, y="test preparation course", x="reading score", palette="ch:25");

# %%
sns.set_theme(color_codes=True) # How gender and race together impact the students exam scores? Female studens in race/ethnicity group E out perform male students, but who are in the group E, in math.
sns.catplot(data=df, x="gender", y="math score", hue="race/ethnicity", kind="bar");
sns.catplot(data=df, x="gender", y="reading score", hue="race/ethnicity", kind="bar");
sns.catplot(data=df, x="gender", y="reading score", hue="race/ethnicity", kind="bar");

# %%
sns.catplot(data=df, x="gender", y="math score", hue="test preparation course", kind="bar");# Female students who completed the test preparation course have received higher grade in math than male students who not completed test preparation course.
sns.catplot(data=df, x="gender", y="reading score", hue="test preparation course", kind="bar");
sns.catplot(data=df, x="gender", y="reading score", hue="test preparation course", kind="bar");
